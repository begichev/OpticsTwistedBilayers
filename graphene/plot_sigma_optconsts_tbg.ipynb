# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import time

path_sigmas = '/Users/daria/mdirac_njit/out/tbg_sigmas'

sigma3 = np.loadtxt(path_sigmas+'/sigma_angle3.txt')
sigma6 = np.loadtxt(path_sigmas+'/sigma_angle6.txt')
sigma9 = np.loadtxt(path_sigmas+'/sigma_angle9.txt')

bound = 3.5
scaleomega = 3.5/1000
omega=np.linspace(1.e-5,bound,1000)[100:1000]


fig,ax=plt.subplots(figsize=(9,9))
ax.plot(sigma3[:,0],
        sigma3[:,1],
        c='y',label='twist bilayer gr '+str(3)+r'$\:^{\circ}$',lw=5)
ax.set_xlabel(r'$\omega$, eV',fontsize=30)
ax.set_ylabel(r'Re $\sigma_{xx}$/$\sigma_0$',fontsize=30)
ax.set_ylim([0.8,6.3])
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)

ax.legend(loc='upper right',fontsize=20)
fig.tight_layout()
realsigmapath = path_sigmas + '/realsigma3.png'
plt.savefig(realsigmapath,dpi=180)
plt.close()

fig,ax=plt.subplots(figsize=(9,9))
ax.plot(sigma6[:,0],
        sigma6[:,1],
        c='y',label='twist bilayer gr '+str(6)+r'$\:^{\circ}$',lw=5)
ax.set_xlabel(r'$\omega$, eV',fontsize=30)
ax.set_ylabel(r'Re $\sigma_{xx}$/$\sigma_0$',fontsize=30)
ax.set_ylim([0.8,6.3])
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)

ax.legend(loc='upper right',fontsize=20)
fig.tight_layout()
realsigmapath = path_sigmas + '/realsigma6.png'
plt.savefig(realsigmapath,dpi=180)
plt.close()

fig,ax=plt.subplots(figsize=(9,9))
ax.plot(sigma9[:,0],
        sigma9[:,1],
        c='y',label='twist bilayer gr '+str(9)+r'$\:^{\circ}$',lw=5)
ax.set_xlabel(r'$\omega$, eV',fontsize=30)
ax.set_ylabel(r'Re $\sigma_{xx}$/$\sigma_0$',fontsize=30)
ax.set_ylim([0.8,6.3])
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)

ax.legend(loc='upper right',fontsize=20)
fig.tight_layout()
realsigmapath = path_sigmas + '/realsigma9.png'
plt.savefig(realsigmapath,dpi=180)
plt.close()

# %%
path_optconsts = '/Users/daria/mdirac_njit/out/tbg_optconsts'
refr3 = np.loadtxt(path_optconsts+'/optconsts3.txt')
refr6 = np.loadtxt(path_optconsts+'/optconsts6.txt')
refr9 = np.loadtxt(path_optconsts+'/optconsts9.txt')

fig,ax=plt.subplots(figsize=(9,9))
ax2 = ax.twinx()
ax.plot(refr3[:,0], refr3[:,1], c='#6C09C9', label='n '+str(3)+r'$\:^{\circ}$')
ax2.plot(refr3[:,0], refr3[:,2], c='g', label='k '+str(3)+r'$\:^{\circ}$')
ax.set_xlabel(r'$\omega$, eV',fontsize=30)
ax.set_ylabel('Refractive index n',c='#6C09C9',fontsize=30)
ax2.set_ylabel('Extinction coefficient k',c='g',fontsize=30)
ax.set_ylim([0,np.max(refr3[:,0])+6.5])
ax2.set_ylim([0,np.max(refr3[:,0])+6.5])
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
ax.legend(loc='upper right',fontsize=20)
ax2.legend(loc='upper left',fontsize=20)
ax.set_xticklabels([0.5,1.0,1.5,2.0,2.5,3.0,3.5],fontsize=15)
ax.set_yticklabels([0,2,4,6,8,10],fontsize=15)
fig.tight_layout()
realsigmapath = path_optconsts + '/optconsts3.png'
plt.savefig(realsigmapath,dpi=180)
plt.close()

fig,ax=plt.subplots(figsize=(9,9))
ax2 = ax.twinx()
ax.plot(refr6[:,0], refr6[:,1], c='#6C09C9', label='n '+str(6)+r'$\:^{\circ}$')
ax2.plot(refr6[:,0], refr6[:,2], c='g', label='k '+str(6)+r'$\:^{\circ}$')
ax.set_xlabel(r'$\omega$, eV',fontsize=30)
ax.set_ylabel('Refractive index n',c='#6C09C9',fontsize=30)
ax2.set_ylabel('Extinction coefficient k',c='g',fontsize=30)
ax.set_ylim([0,np.max(refr6[:,0])+4.5])
ax2.set_ylim([0,np.max(refr6[:,0])+4.5])
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
ax.legend(loc='upper right',fontsize=20)
ax2.legend(loc='upper left',fontsize=20)
ax.set_xticklabels([0.5,1.0,1.5,2.0,2.5,3.0,3.5],fontsize=15)
ax.set_yticklabels([0,1,2,3,4,5,6,7,8],fontsize=15)
fig.tight_layout()
realsigmapath = path_optconsts + '/optconsts6.png'
plt.savefig(realsigmapath,dpi=180)
plt.close()

fig,ax=plt.subplots(figsize=(9,9))
ax2 = ax.twinx()
ax.plot(refr9[:,0], refr9[:,1], c='#6C09C9', label='n '+str(9)+r'$\:^{\circ}$')
ax2.plot(refr9[:,0], refr9[:,2], c='g', label='k '+str(9)+r'$\:^{\circ}$')
ax.set_xlabel(r'$\omega$, eV',fontsize=30)
ax.set_ylabel('Refractive index n',c='#6C09C9',fontsize=30)
ax2.set_ylabel('Extinction coefficient k',c='g',fontsize=30)
ax.set_ylim([0,np.max(refr9[:,0])+2.5])
ax2.set_ylim([0,np.max(refr9[:,0])+2.5])
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
ax.legend(loc='upper right',fontsize=20)
ax2.legend(loc='upper left',fontsize=20)
ax.set_xticklabels([0.5,1.0,1.5,2.0,2.5,3.0,3.5],fontsize=15)
ax.set_yticklabels([0,1,2,3,4,5,6],fontsize=15)
fig.tight_layout()
realsigmapath = path_optconsts + '/optconsts9.png'
plt.savefig(realsigmapath,dpi=180)
plt.close()
# Out:
# <ipython-input-37-88dcd1a7e105>:19: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels([0.5,1.0,1.5,2.0,2.5,3.0,3.5],fontsize=15)
# <ipython-input-37-88dcd1a7e105>:20: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels([0,2,4,6,8,10],fontsize=15)
# <ipython-input-37-88dcd1a7e105>:39: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels([0.5,1.0,1.5,2.0,2.5,3.0,3.5],fontsize=15)
# <ipython-input-37-88dcd1a7e105>:40: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels([0,1,2,3,4,5,6,7,8],fontsize=15)
# <ipython-input-37-88dcd1a7e105>:59: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels([0.5,1.0,1.5,2.0,2.5,3.0,3.5],fontsize=15)
# <ipython-input-37-88dcd1a7e105>:60: UserWarning: FixedFormatter should only be used together with FixedLocator
# ...
